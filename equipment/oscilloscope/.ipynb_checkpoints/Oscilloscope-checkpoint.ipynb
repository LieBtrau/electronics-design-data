# %% [markdown]
# Budget : ?
#
# # Requirements
# * ≥ 350MHz bandwidth
# * 4 channels
# * big screen
#
# # Budget
# <€6K
#
# # Options
#
# ## Siglent SDS2354X HD
# * € 5,662.80
# * 2x200Mpts or 4x 100Mpts
# * 2x2Gs/s or 4x 1Gs/s
# * 12bit ADC
# * ENOB : 8.4bits
# * 65µVrms noise at 1mV/div
# * 1ns peak detect
# * trigger : Qualified, Nth edge,Setup/hold, delay
# * Gating measurement, and measurements on Math, History and Ref
# * digital Voltmeter
# * hardware frequency counter 7digits
# * 25MHz AWG optional
# * 100K wfm/s
# * Channel isolation 70dBc
# * sequence 80K wfms
# * Math : FFT, +, -, x, ÷, ∫dt, d/dt, √, Identity, Negation, |x|, Sign, e^x, 10^x, ln, lg, Interpolation, Max hold, Min hold, ERES, Average, Formula Editor
# * 70µVrms noise at 500MHz BW
# * 10.1" 1024x600
# * DC-gain accuracy 3%
# * SFDR > 45dBc
# * Offset accuracy 0.5%
# * time base 2ppm
# * Measure setup time/hold time
# * Length × Height × Width = 317.2 mm × 236.0 mm × 149.0 mm
# * 4.1kg
#
# ## Teledyne WaveSurfer 4034HD
# * 12.1" screen, 1280 x 800 pixels
# * ENOB : 8.6bits
# * 70µVrms noise at 1mV/div
# * 2.5 GS/s on 4 Ch, 5 GS/s on 2 Ch
# * Serial decoding is a paid option
# * 5 digit frequency counter
#
# ## Siglent SDS2354X Plus
# * € 3,144.79
# * 50MHz AWG optional
# * 120K wfm/s
# * 80µVrms noise at 500MHz BW
# * DC-gain accuracy 1.5%
# * SFDR > 40dBc
# * Offset accuracy 1.5%
# * time base 1ppm
# * no digital voltmeter
# * Math : +, -, * , ÷, FFT, d/dt, ∫dt, √, Identity, Negation, |x|, Sign, e^x, 10^x, ln, lg, Interpolation, Average, ERES, Formula Editor
# * Length x Height x Width = 352 mm × 224 mm × 111 mm
# * 4.8kg
#
# ## Siglent SDS5034X
# * € 3,471.49
# * 2x5Gs/s or 4x2.5Gs/s
# * 2x250Mpts or 4x 125Mpts
# * 8bit ADC
# * 110K wfm/s
# * 400ps peak detect
# * no Nth edge, Setup/hold, Delay
# * sequence 100K wfms
# * SFDR 32dBc
# * Channel isolation 34dBc
# * no slope measurement, nor tsu & thold measurement
# * Math : +, -, *, /, FFT, d/dt, ∫dt, square root, Formula Editor
# * digital Voltmeter
# * Length * Width * Height = 370 mm × 231 mm × 144 mm
# * G.W 5.4 kg(2-ch); 5.6 kg(4-ch)
#
# ## R&S RTB2K
# * Might have good analog front end, but measurement capabilities are limited
# * no 50ohm input
